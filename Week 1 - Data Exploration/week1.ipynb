# %%
import pandas as pd

# %%
df = pd.read_json("Sarcasm_Headlines_Dataset_v2.json", lines=True)

# %%
print("Rows, Columns:", df.shape)
print("\nColumns:", df.columns.tolist())
# Out:
# Rows, Columns: (28619, 3)
#
# Columns: ['is_sarcastic', 'headline', 'article_link']

# %%
label_counts = df["is_sarcastic"].value_counts()
print("\nClass Balance:")
print(label_counts)
# Out:
# Class Balance:
# is_sarcastic
# 0    14985
# 1    13634
# Name: count, dtype: int64

# %%
print("\nClass Balance (percent):")
print(label_counts / len(df) * 100)
# Out:
# Class Balance (percent):
# is_sarcastic
# 0    52.36032
# 1    47.63968
# Name: count, dtype: float64

# %%
print("\nSample headlines:")
print(df[["headline", "is_sarcastic"]].sample(5))
# Out:
# Sample headlines:
#                                                 headline  is_sarcastic
# 11260  mar-a-lago member complains about loud, obnoxi...             1
# 4267   chromat features not 1, but 2 plus-size models...             0
# 23310                            area panties in a bunch             1
# 17004  clooney scouting locations for darfur-based ro...             1
# 13871  china unable to recruit hackers fast enough to...             1
